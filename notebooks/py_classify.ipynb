# %% [markdown]
# # run class 1 unit test

# %%
import mn_classification_rules

# %%
from mn_classification_rules import test

# %%
import unittest

loader = unittest.TestLoader()
suite = loader.discover('../src/mn_classification_rules/test', pattern='test_residential.py')

unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_class_1a (test_residential.TestResidentialClassification.test_class_1a) ... ok
# test_class_1b (test_residential.TestResidentialClassification.test_class_1b) ... ok
# test_class_1c (test_residential.TestResidentialClassification.test_class_1c) ... FAIL
# test_class_1d (test_residential.TestResidentialClassification.test_class_1d) ... ok
# test_unclassified (test_residential.TestResidentialClassification.test_unclassified) ... ok
#
# ...
# FAIL: test_class_1c (test_residential.TestResidentialClassification.test_class_1c)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/workspaces/mn-tax-knowledge-modeling/src/mn_classification_rules/test/test_residential.py", line 24, in test_class_1c
#     self.assertEqual(classify_residential(parcel, owner), "1c")
# AssertionError: '1a' != '1c'
# - 1a
# + 1c
#
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.025s
#
# ...
